# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhivyaindhu/SKILL_UPGRADE_AUGUST_TASK_1/blob/main/Untitled94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task-1:
# Data preprocessing and Data Cleaning

# %%
import numpy as np
import pandas as pd
data=pd.read_csv("/content/movies_1980_2020_30k.csv")
data.head()
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         30000 non-null  object
#  1   Director      30000 non-null  object
#  2   Genre         30000 non-null  object
#  3   Release Date  30000 non-null  object
#  4   Duration      30000 non-null  int64
#  5   Rating        30000 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.4+ MB
#            Duration        Rating
# count  30000.000000  30000.000000
# mean     120.131033      5.519867
# std       34.981221      2.591138
# min       60.000000      1.000000
# 25%       90.000000      3.300000
# 50%      120.000000      5.500000
# 75%      150.000000      7.700000
# max      180.000000     10.000000

# %%
data.isnull().sum()
# Out:
# Title           0
# Director        0
# Genre           0
# Release Date    0
# Duration        0
# Rating          0
# dtype: int64

# %%
data.isnull()
# Out:
#        Title  Director  Genre  Release Date  Duration  Rating
# 0      False     False  False         False     False   False
# 1      False     False  False         False     False   False
# 2      False     False  False         False     False   False
# 3      False     False  False         False     False   False
# 4      False     False  False         False     False   False
# ...      ...       ...    ...           ...       ...     ...
# 29995  False     False  False         False     False   False
# 29996  False     False  False         False     False   False
# 29997  False     False  False         False     False   False
# 29998  False     False  False         False     False   False
# 29999  False     False  False         False     False   False
#
# [30000 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['Title', 'Director', 'Genre', 'Release Date', 'Duration', 'Rating'], dtype='object')

# %%
data.shape
# Out:
# (30000, 6)

# %%
df=pd.DataFrame(data)
df.drop(columns=['Release Date'],inplace=True)
df.head()
# Out:
#                  Title         Director        Genre  Duration  Rating
# 0  Key entire popular.   Anthony Becker       Horror       102     6.8
# 1  Gun husband reveal.  William Johnson  Documentary        92     7.6
# 2         Crime cover.           Amy Le        Drama       144     5.5
# 3           Challenge.  Andrea Martinez      Romance       161     2.0
# 4         Close study.  Michael Rodgers      Fantasy       177     3.7

# %% [markdown]
# Sampling

# %%
df_reduced=df.sample(n=1500)
print(df_reduced)
# Out:
#                           Title             Director        Genre  Duration  \
# 16886  Blood experience forget.      Christine Solis       Comedy        60
# 2947           Rate allow hear.       Jennifer Lopez      Romance       115
# 27106              Could enter.  Kathleen Montgomery       Horror       124
# 8291         Worry traditional.  Christine Carpenter       Sci-Fi        66
# 28567     Knowledge us several.        Richard Downs       Action        80
# ...                         ...                  ...          ...       ...
# 758               Those do win.         Alison Clark  Documentary       179
# 25059               Song today.     William Thornton      Romance       143
# 23779   Age place attorney act.        Thomas Nelson    Adventure       152
# 10120         Voice trial task.      Brittany Newman       Horror        77
# 11332              Seven civil.       Holly Phillips      Romance        74
#
#        Rating
# 16886     3.3
# 2947      8.1
# ...

# %%
df['Rating']= df['Rating'].astype(int)
df.head()
# Out:
#                  Title         Director        Genre  Duration  Rating
# 0  Key entire popular.   Anthony Becker       Horror       102       6
# 1  Gun husband reveal.  William Johnson  Documentary        92       7
# 2         Crime cover.           Amy Le        Drama       144       5
# 3           Challenge.  Andrea Martinez      Romance       161       2
# 4         Close study.  Michael Rodgers      Fantasy       177       3

# %% [markdown]
# Encoded Data

# %%
df_encoded=pd.get_dummies(df,columns=['Genre'])
df_encoded.head()
# Out:
#                  Title         Director  Duration  Rating  Genre_Action  \
# 0  Key entire popular.   Anthony Becker       102       6         False
# 1  Gun husband reveal.  William Johnson        92       7         False
# 2         Crime cover.           Amy Le       144       5         False
# 3           Challenge.  Andrea Martinez       161       2         False
# 4         Close study.  Michael Rodgers       177       3         False
#
#    Genre_Adventure  Genre_Comedy  Genre_Documentary  Genre_Drama  \
# 0            False         False              False        False
# 1            False         False               True        False
# 2            False         False              False         True
# 3            False         False              False        False
# 4            False         False              False        False
#
#    Genre_Fantasy  Genre_Horror  Genre_Romance  Genre_Sci-Fi  Genre_Thriller
# ...

# %% [markdown]
# Interquartile range for finding outliers

# %%
import pandas as pd
Q1 = df['Rating'].quantile(0.25)
Q3 = df['Rating'].quantile(0.75)

# Calculate IQR (Interquartile Range)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find outliers
outliers = df[(df['Rating'] < lower_bound) | (df['Rating'] > upper_bound)]

# Print outliers
print("Outliers in column", 'Rating')
print(outliers)
# Out:
# Outliers in column Rating
# Empty DataFrame
# Columns: [Title, Director, Genre, Duration, Rating]
# Index: []

# %% [markdown]
# Indexing by Time

# %%
df['Duration'] = pd.to_datetime(df['Duration'])
df.head()
# Out:
#                  Title         Director        Genre  \
# 0  Key entire popular.   Anthony Becker       Horror
# 1  Gun husband reveal.  William Johnson  Documentary
# 2         Crime cover.           Amy Le        Drama
# 3           Challenge.  Andrea Martinez      Romance
# 4         Close study.  Michael Rodgers      Fantasy
#
#                        Duration  Rating
# 0 1970-01-01 00:00:00.000000102       6
# 1 1970-01-01 00:00:00.000000092       7
# 2 1970-01-01 00:00:00.000000144       5
# 3 1970-01-01 00:00:00.000000161       2
# 4 1970-01-01 00:00:00.000000177       3

# %%
df.to_csv('cleaned_dataset.csv', index=False)
